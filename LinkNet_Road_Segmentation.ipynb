# %% [markdown]
# # LinkNet Road Segmentation
# DataSet https://www.kaggle.com/insaff/massachusetts-roads-dataset

# %%
    
import os
import sys
import shutil
import glob,math
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import cv2
import numpy as np
import matplotlib.pyplot as plt
import zipfile
import functools
import tensorflow as tf
import random
print(tf.__version__)
#import tensorflow.contrib as tfcontrib
import tensorflow_addons as tfa
from tensorflow.python.keras import layers
from tensorflow.python.keras import losses
from tensorflow.python.keras import models
from tensorflow.python.keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['axes.grid'] = False
mpl.rcParams['figure.figsize'] = (12,12)

from sklearn.model_selection import train_test_split
import matplotlib.image as mpimg
import pandas as pd
height = 512
width = 512
# Out:
# 2.2.0

# %% [markdown]
# <h1>Data Preprocessing</h2>
#     <h4><li>crop data into smaller tiles 512*512 px</li>
#     <li>clean data where no road mask present </li> </h4>

# %%
def dir_create(path):
    if (os.path.exists(path)) and (os.listdir(path) != []):
        shutil.rmtree(path)
        os.makedirs(path)
    if not os.path.exists(path):
        os.makedirs(path)
        
def crop(input_file, height, width):
    img = Image.open(input_file)
    img_width, img_height = img.size
    width_right=width
    height_bottom=height
    for i in range(math.ceil(img_height/height)):
        for j in range(math.ceil(img_width/width)):
            
            if (j+1)*width > img_width:
                width_right = img_width
            if (i+1)*height > img_height:
                height_bottom = img_height
            if (j+1)*width <= img_width and (i+1)*height <= img_height:
                height_bottom = (i+1)*height
                width_right = (j+1)*width
                
            box = (j*width, i*height, width_right, height_bottom)  
            #print(box,i,j,math.ceil(img_width//width),img_width, img_height)
            yield img.crop(box)
            

def split(inp_img_dir, inp_msk_dir, out_dir, height, width, 
          start_num):
    image_dir = os.path.join(out_dir, 'images')
    mask_dir = os.path.join(out_dir, 'masks')
    dir_create(out_dir)
    dir_create(image_dir)
    dir_create(mask_dir)
    img_list = [f for f in
                os.listdir(inp_img_dir)
                if os.path.isfile(os.path.join(inp_img_dir, f))]
    file_num = 0
    for infile in img_list:
        infile_path = os.path.join(inp_img_dir, infile)
        mask_path = os.path.join(inp_msk_dir,
                                   infile.split('.')[0] + '.png')
        
        if not os.path.exists(infile_path) or not os.path.exists(mask_path):
            print('file not exists:',infile.split('.')[0] + '.png')
            continue
        
        for k, piece in enumerate(crop(infile_path,
                                       height, width), start_num):
            img = Image.new('RGB', (height, width), 0)
            img.paste(piece)
            img_path = os.path.join(image_dir, 
                                    infile.split('.')[0]+ '_'
                                    + str(k).zfill(5) + '.png')
            img.save(img_path)
        infile_path = os.path.join(inp_msk_dir,
                                   infile.split('.')[0] + '.png')
        for k, piece in enumerate(crop(infile_path,
                                       height, width), start_num):
            msk = Image.new('RGB', (height, width), 0)
            msk.paste(piece)
            msk_path = os.path.join(mask_dir,
                                    infile.split('.')[0] + '_'
                                    + str(k).zfill(5) + '.png')
            msk.save(msk_path)
        file_num += 1
        sys.stdout.write("\rFile %s was processed." % file_num)
        sys.stdout.flush()

# %%
inp_img_dir = '/home/ricky/workspace/sat/data/road_segmentation_ideal/testing/input'
inp_msk_dir = '/home/ricky/workspace/sat/data/road_segmentation_ideal/testing/output'
out_dir = './test'
height = 512
width = 512
start_num = 1

split(inp_img_dir, inp_msk_dir, out_dir, height, width, 
          start_num)
# Out:
# File 13 was processed.

# %% [markdown]
#  <h4><li>clean images where no mask present</li> </h4>

# %%
inp_img_dir = '/home/ricky/workspace/sat/data/road_segmentation_ideal/training/input'
inp_msk_dir = '/home/ricky/workspace/sat/data/road_segmentation_ideal/training/output'
out_dir = './train'
height = 512
width = 512
start_num = 1

split(inp_img_dir, inp_msk_dir, out_dir, height, width, 
          start_num)
# Out:
# File 9 was processed.file not exists: img-526.png
# file not exists: img-962.png
# file not exists: img-779.png
# File 10 was processed.file not exists: img-730.png
# File 12 was processed.file not exists: img-522.png
# File 19 was processed.file not exists: img-410.png
# File 23 was processed.file not exists: img-972.png
# file not exists: img-926.png
# File 26 was processed.file not exists: img-866.png
# file not exists: img-404.png
# File 28 was processed.file not exists: img-438.png
# file not exists: img-885.png
# file not exists: img-329.png
# File 34 was processed.file not exists: img-379.png
# file not exists: img-260.png
# File 36 was processed.file not exists: img-345.png
# File 38 was processed.file not exists: img-538.png
# file not exists: img-648.png
# File 42 was processed.file not exists: img-558.png
# File 46 was processed.file not exists: img-525.png
# file not exists: img-253.png
# file not exists: img-178.png
# File 47 was processed.file not exists: img-569.png
# File 51 was processed.file not exists: img-733.png
# File 53 was processed.file not exists: img-338.png
# File 58 was processed.file not exists: img-500.png
# File 59 was processed.file not exists: img-1095.png
# File 61 was processed.file not exists: img-1079.png
# file not exists: img-426.png
# File 63 was processed.file not exists: img-745.png
# File 72 was processed.file not exists: img-320.png
# File 86 was processed.file not exists: img-771.png
# File 88 was processed.file not exists: img-807.png
# File 92 was processed.file not exists: img-971.png
# File 93 was processed.file not exists: img-728.png
# file not exists: img-513.png
# File 98 was processed.file not exists: img-415.png
# File 99 was processed.file not exists: img-917.png
# File 102 was processed.file not exists: img-691.png
# file not exists: img-506.png
# File 107 was processed.file not exists: img-837.png
# file not exists: img-1070.png
# File 125 was processed.file not exists: img-395.png
# file not exists: img-748.png
# File 127 was processed.file not exists: img-713.png
# File 129 was processed.file not exists: img-747.png
# File 137 was processed.file not exists: img-210.png
# file not exists: img-1050.png
# file not exists: img-944.png
# File 140 was processed.file not exists: img-284.png
# file not exists: img-934.png
# file not exists: img-835.png
# File 142 was processed.file not exists: img-694.png
# File 148 was processed.file not exists: img-4.png
# File 149 was processed.file not exists: img-425.png
# File 162 was processed.file not exists: img-262.png
# file not exists: img-401.png
# File 164 was processed.file not exists: img-758.png
# File 165 was processed.file not exists: img-445.png
# File 170 was processed.file not exists: img-922.png
# File 174 was processed.file not exists: img-1094.png
# File 179 was processed.file not exists: img-137.png
# file not exists: img-644.png
# File 180 was processed.file not exists: img-314.png
# file not exists: img-772.png
# File 181 was processed.file not exists: img-643.png
# File 187 was processed.file not exists: img-982.png
# File 189 was processed.file not exists: img-1057.png
# file not exists: img-904.png
# file not exists: img-624.png
# File 202 was processed.file not exists: img-873.png
# File 205 was processed.file not exists: img-283.png
# File 215 was processed.file not exists: img-918.png
# file not exists: img-48.png
# file not exists: img-419.png
# File 221 was processed.file not exists: img-201.png
# File 223 was processed.file not exists: img-852.png
# File 226 was processed.file not exists: img-726.png
# file not exists: img-374.png
# file not exists: img-359.png
# File 227 was processed.file not exists: img-761.png
# File 237 was processed.file not exists: img-288.png
# File 239 was processed.file not exists: img-605.png
# file not exists: img-946.png
# File 247 was processed.file not exists: img-770.png
# File 248 was processed.file not exists: img-1105.png
# File 251 was processed.file not exists: img-755.png
# file not exists: img-553.png
# File 254 was processed.file not exists: img-258.png
# File 258 was processed.file not exists: img-978.png
# File 265 was processed.file not exists: img-1039.png
# File 266 was processed.file not exists: img-421.png
# File 272 was processed.file not exists: img-259.png
# File 276 was processed.file not exists: img-1100.png
# File 280 was processed.file not exists: img-1034.png
# File 283 was processed.file not exists: img-864.png
# File 285 was processed.file not exists: img-455.png
# File 287 was processed.file not exists: img-266.png
# File 303 was processed.file not exists: img-1059.png
# File 306 was processed.file not exists: img-393.png
# File 309 was processed.file not exists: img-1087.png
# File 311 was processed.file not exists: img-402.png
# File 316 was processed.file not exists: img-34.png
# File 319 was processed.file not exists: img-923.png
# file not exists: img-557.png
# File 323 was processed.file not exists: img-255.png
# file not exists: img-257.png
# File 324 was processed.file not exists: img-843.png
# File 325 was processed.file not exists: img-692.png
# File 327 was processed.file not exists: img-1106.png
# File 328 was processed.file not exists: img-213.png
# File 331 was processed.file not exists: img-808.png
# File 335 was processed.file not exists: img-539.png
# file not exists: img-540.png
# file not exists: img-365.png
# File 337 was processed.file not exists: img-332.png
# File 338 was processed.file not exists: img-1088.png
# File 345 was processed.file not exists: img-941.png
# File 346 was processed.file not exists: img-63.png
# File 347 was processed.file not exists: img-523.png
# File 349 was processed.file not exists: img-175.png
# file not exists: img-287.png
# File 350 was processed.file not exists: img-850.png
# File 354 was processed.file not exists: img-394.png
# File 355 was processed.file not exists: img-440.png
# file not exists: img-1049.png
# file not exists: img-1045.png
# File 359 was processed.file not exists: img-1.png
# file not exists: img-273.png
# file not exists: img-1107.png
# file not exists: img-484.png
# File 363 was processed.file not exists: img-252.png
# File 364 was processed.file not exists: img-757.png
# File 368 was processed.file not exists: img-731.png
# File 369 was processed.file not exists: img-475.png
# File 371 was processed.file not exists: img-416.png
# file not exists: img-436.png
# File 379 was processed.file not exists: img-647.png
# File 383 was processed.file not exists: img-816.png
# File 389 was processed.file not exists: img-1052.png
# file not exists: img-367.png
# File 390 was processed.file not exists: img-75.png
# File 391 was processed.file not exists: img-303.png
# File 400 was processed.file not exists: img-276.png
# file not exists: img-844.png
# File 406 was processed.file not exists: img-494.png
# File 418 was processed.file not exists: img-1013.png
# File 419 was processed.file not exists: img-61.png
# file not exists: img-423.png
# File 420 was processed.file not exists: img-737.png
# file not exists: img-508.png
# File 426 was processed.file not exists: img-1044.png
# File 439 was processed.file not exists: img-853.png
# File 444 was processed.file not exists: img-1062.png
# File 451 was processed.file not exists: img-420.png
# File 454 was processed.file not exists: img-422.png
# File 458 was processed.file not exists: img-209.png
# File 459 was processed.file not exists: img-1010.png
# File 460 was processed.file not exists: img-417.png
# File 462 was processed.file not exists: img-1029.png
# File 465 was processed.file not exists: img-625.png
# File 468 was processed.file not exists: img-373.png
# File 471 was processed.file not exists: img-896.png
# File 472 was processed.file not exists: img-411.png
# File 473 was processed.file not exists: img-836.png
# file not exists: img-207.png
# file not exists: img-556.png
# File 476 was processed.file not exists: img-1096.png
# file not exists: img-541.png
# File 489 was processed.file not exists: img-734.png
# File 498 was processed.file not exists: img-903.png
# File 500 was processed.file not exists: img-297.png
# File 505 was processed.file not exists: img-245.png
# file not exists: img-277.png
# File 509 was processed.file not exists: img-353.png
# file not exists: img-486.png
# file not exists: img-1076.png
# File 512 was processed.file not exists: img-1068.png
# File 516 was processed.file not exists: img-418.png
# File 522 was processed.file not exists: img-545.png
# file not exists: img-441.png
# File 523 was processed.file not exists: img-1024.png
# File 525 was processed.file not exists: img-315.png
# File 526 was processed.file not exists: img-263.png
# file not exists: img-405.png
# File 531 was processed.file not exists: img-392.png
# file not exists: img-352.png
# File 532 was processed.file not exists: img-838.png
# File 536 was processed.file not exists: img-47.png
# File 537 was processed.file not exists: img-177.png
# File 543 was processed.file not exists: img-274.png
# File 547 was processed.file not exists: img-732.png
# File 552 was processed.file not exists: img-15.png
# file not exists: img-649.png
# File 556 was processed.file not exists: img-499.png
# File 559 was processed.file not exists: img-727.png
# file not exists: img-485.png
# file not exists: img-874.png
# File 566 was processed.file not exists: img-254.png
# File 573 was processed.file not exists: img-1080.png
# file not exists: img-1071.png
# file not exists: img-650.png
# file not exists: img-179.png
# File 577 was processed.file not exists: img-729.png
# file not exists: img-1011.png
# File 579 was processed.file not exists: img-501.png
# File 585 was processed.file not exists: img-746.png
# File 589 was processed.file not exists: img-570.png
# File 594 was processed.file not exists: img-754.png
# File 595 was processed.file not exists: img-211.png
# File 597 was processed.file not exists: img-3.png
# File 605 was processed.file not exists: img-894.png
# File 607 was processed.file not exists: img-1040.png
# File 611 was processed.file not exists: img-980.png
# file not exists: img-521.png
# File 615 was processed.file not exists: img-693.png
# File 618 was processed.file not exists: img-954.png
# file not exists: img-544.png
# File 622 was processed.file not exists: img-992.png
# File 624 was processed.file not exists: img-5.png
# file not exists: img-403.png
# file not exists: img-378.png
# file not exists: img-275.png
# file not exists: img-321.png
# File 625 was processed.file not exists: img-261.png
# File 631 was processed.file not exists: img-185.png
# file not exists: img-1023.png
# File 632 was processed.file not exists: img-339.png
# file not exists: img-1001.png
# File 634 was processed.file not exists: img-524.png
# file not exists: img-925.png
# File 644 was processed.file not exists: img-865.png
# File 648 was processed.file not exists: img-527.png
# file not exists: img-1035.png
# File 655 was processed.file not exists: img-515.png
# File 659 was processed.file not exists: img-725.png
# file not exists: img-942.png
# File 667 was processed.file not exists: img-296.png
# File 672 was processed.file not exists: img-924.png
# File 673 was processed.file not exists: img-712.png
# File 677 was processed.file not exists: img-919.png
# File 679 was processed.file not exists: img-546.png
# File 680 was processed.file not exists: img-778.png
# File 685 was processed.file not exists: img-385.png
# File 687 was processed.file not exists: img-642.png
# File 689 was processed.file not exists: img-331.png
# File 693 was processed.file not exists: img-344.png
# File 696 was processed.file not exists: img-464.png
# file not exists: img-195.png
# File 699 was processed.file not exists: img-289.png
# File 700 was processed.file not exists: img-809.png
# file not exists: img-138.png
# File 701 was processed.file not exists: img-212.png
# File 703 was processed.file not exists: img-286.png
# file not exists: img-366.png
# File 705 was processed.file not exists: img-322.png
# file not exists: img-265.png
# File 711 was processed.file not exists: img-390.png
# File 713 was processed.file not exists: img-886.png
# file not exists: img-905.png
# File 724 was processed.file not exists: img-236.png
# file not exists: img-337.png
# file not exists: img-302.png
# File 729 was processed.file not exists: img-424.png
# File 733 was processed.file not exists: img-565.png
# File 738 was processed.file not exists: img-1038.png
# File 740 was processed.file not exists: img-285.png
# file not exists: img-666.png
# File 743 was processed.file not exists: img-206.png
# File 747 was processed.file not exists: img-1012.png
# File 750 was processed.file not exists: img-851.png
# File 751 was processed.file not exists: img-577.png
# file not exists: img-884.png
# File 757 was processed.file not exists: img-330.png
# File 758 was processed.file not exists: img-979.png
# file not exists: img-208.png
# File 760 was processed.file not exists: img-351.png
# File 761 was processed.file not exists: img-227.png
# File 762 was processed.file not exists: img-400.png
# File 763 was processed.file not exists: img-589.png
# File 768 was processed.file not exists: img-214.png
# File 770 was processed.file not exists: img-493.png
# File 771 was processed.file not exists: img-439.png
# File 785 was processed.file not exists: img-1061.png
# file not exists: img-82.png
# File 786 was processed.file not exists: img-256.png
# File 787 was processed.file not exists: img-895.png
# File 790 was processed.file not exists: img-805.png
# File 791 was processed.file not exists: img-945.png
# File 794 was processed.file not exists: img-1018.png
# File 795 was processed.file not exists: img-1101.png
# file not exists: img-806.png
# File 796 was processed.file not exists: img-626.png
# File 798 was processed.file not exists: img-474.png
# File 801 was processed.file not exists: img-103.png
# file not exists: img-1033.png
# File 804 was processed.file not exists: img-251.png
# file not exists: img-437.png
# file not exists: img-84.png
# file not exists: img-313.png

# %% [markdown]
#  <h4><li>clean images where no road mask present</li> </h4>

# %%
blank=[]
for f in glob.glob('/home/ricky/workspace/sat/train/masks/*.png'):
    img = cv2.imread(f,0)
    blank_pixel = np.sum(img)
    if(blank_pixel <1):
        blank.append(f)
        
len(blank)
# Out:
# 534

# %%
imgplot = plt.imshow(cv2.imread(blank[305].replace('masks','images'),0))
plt.show()

# %%
imgplot = plt.imshow(cv2.imread(blank[305],3))
plt.show(),
# Out:
# (None,)

# %%
for b in blank:
    blank_files= os.path.basename(b)
    os.remove('/home/ricky/workspace/sat/train/masks/'+blank_files)
    os.remove('/home/ricky/workspace/sat/train/images/'+blank_files)

# %%
blank_post=[]
for f in glob.glob('/home/ricky/workspace/sat/train/masks/*.png'):
    img = cv2.imread(f,0)
    blank_pixel = np.sum(img)
    if(blank_pixel <1):
        blank_post.append(f)
        
len(blank_post)
# Out:
# 0

# %% [markdown]
# # Data Visualization & Files

# %%
base='/home/ricky/workspace/sat/train/'
train_raw_images=[]
train_label_files=[]
for file in glob.glob("/home/ricky/workspace/sat/train/images/*.png"):
    blank_files= os.path.basename(file)
    train_raw_images.append(file)
    train_label_files.append(file.replace("images","masks"))
len(train_raw_images),len(train_label_files)
# Out:
# (6702, 6702)

# %%
base='/home/ricky/workspace/sat/test/'
test_raw_images=[]
test_label_files=[]
for file in glob.glob("/home/ricky/workspace/sat/test/images/*.png"):
    blank_files= os.path.basename(file)
    test_raw_images.append(file)
    test_label_files.append(file.replace("images","masks"))
len(test_raw_images),len(test_label_files)
# Out:
# (117, 117)

# %%
display_num = 5
def plotimages(imgs,masks):
    r_choices = np.random.choice(len(imgs), display_num)

    plt.figure(figsize=(10, 15))
    for i in range(0, display_num * 2, 2):
      img_num = r_choices[i // 2]
      x_pathname = imgs[img_num]
      y_pathname = masks[img_num]

      plt.subplot(display_num, 2, i + 1)
      plt.imshow(mpimg.imread(x_pathname))
      plt.title("Original Image")

      example_labels = Image.open(y_pathname)
      label_vals = np.unique(example_labels)

      plt.subplot(display_num, 2, i + 2)
      plt.imshow(example_labels)
      plt.title("Masked Image")  

    plt.suptitle("Examples of road and Masks")
    plt.show()
plotimages(train_raw_images,train_label_files)

# %%
plotimages(test_raw_images,test_label_files)

# %% [markdown]
# # Custom Data generator & Test Train Split

# %%
x_train_filenames, x_val_filenames, y_train_filenames, y_val_filenames = train_test_split(train_raw_images,train_label_files, test_size=0.08, random_state=17,shuffle=True)
len(x_val_filenames),len(x_train_filenames)
# Out:
# (537, 6165)

# %%
img_shape = (512, 512, 3)
batch_size = 2
epochs = 5

def _process_pathnames(fname, label_path):
    # We map this function onto each pathname pair
    img_str = tf.io.read_file(fname)
    img = tf.image.decode_png(img_str, channels=3)

    label_img_str = tf.io.read_file(label_path)
    # These are gif images so they return as (num_frames, h, w, c)
    label_img = tf.image.decode_png(label_img_str)
    # The label image should only have values of 1 or 0, indicating pixel wise
    # object (car) or not (background). We take the first channel only.
    label_img = label_img[:, :, 0]
    label_img = tf.expand_dims(label_img, axis=-1)
    return img, label_img


# In[11]:


def shift_img(output_img, label_img, width_shift_range, height_shift_range):
    """This fn will perform the horizontal or vertical shift"""
    if width_shift_range or height_shift_range:
        if width_shift_range:
            width_shift_range = tf.random.uniform([],
                                                  -width_shift_range * img_shape[1],
                                                  width_shift_range * img_shape[1])
        if height_shift_range:
            height_shift_range = tf.random.uniform([],
                                                   -height_shift_range * img_shape[0],
                                                   height_shift_range * img_shape[0])
        # Translate both
        output_img = tfa.image.translate(output_img,
                                               [width_shift_range, height_shift_range])
        label_img = tfa.image.translate(label_img,
                                              [width_shift_range, height_shift_range])
    return output_img, label_img


# In[12]:


def flip_img(horizontal_flip, tr_img, label_img):
    if horizontal_flip:
        flip_prob = tf.random.uniform([], 0.0, 1.0)
        tr_img, label_img = tf.cond(tf.less(flip_prob, 0.5),
                                    lambda: (tf.image.flip_left_right(tr_img), tf.image.flip_left_right(label_img)),
                                    lambda: (tr_img, label_img))
    return tr_img, label_img


# In[13]:


def _augment(img,
             label_img,
             resize=None,  # Resize the image to some size e.g. [256, 256]
             scale=1,  # Scale image e.g. 1 / 255.
             hue_delta=0.2,  # Adjust the hue of an RGB image by random factor
             horizontal_flip=False,  # Random left right flip,
             width_shift_range=0,  # Randomly translate the image horizontally
             height_shift_range=0,
             brightness_delta=0,
             lower_contrast=0,
             upper_contrast=0):  # Randomly translate the image vertically
    if resize is not None:
        pass
        # Resize both images
        #label_img = tf.image.resize_image_with_crop_or_pad(label_img, resize[0],resize[1])
        #img = tf.image.resize_image_with_crop_or_pad(img, resize[0],resize[1])

    if hue_delta:
        img = tf.image.random_hue(img, hue_delta)

    if lower_contrast and upper_contrast:
        img = tf.image.random_contrast(img, lower_contrast, upper_contrast)

    if brightness_delta:
        img = tf.image.random_brightness(img, brightness_delta)

    img, label_img = flip_img(horizontal_flip, img, label_img)
    img, label_img = shift_img(img, label_img, width_shift_range, height_shift_range)
    label_img = tf.cast(label_img, tf.float32) * scale
    img = tf.cast(img,tf.float32) * scale
    return img, label_img


def _tb_augment(img, label_img):
    #label_img = tf.image.resize_image_with_crop_or_pad(label_img, [img_shape[0], img_shape[1]])
    #img = tf.image.resize_image_with_crop_or_pad(img, [img_shape[0], img_shape[1]])

    label_img = tf.cast(label_img,tf.float32) * (1 / 255.)
    img = tf.cast(img,tf.float32) * (1 / 255.)

    return img, label_img


# In[14]:


def get_tb_dataset(fnames,
                   lnames,
                   preproc_fn=functools.partial(_tb_augment),
                   threads=6,
                   batch_set_size=1,
                   shuffle=False):
    filenames, labels = zip(*random.sample(list(zip(fnames, lnames)), 300))

    num_x = len(filenames)
    # Create a dataset from the filenames and labels
    dataset = tf.data.Dataset.from_tensor_slices((list(filenames), list(labels)))

    # Map our preprocessing function to every element in our dataset, taking
    # advantage of multithreading
    dataset = dataset.map(_process_pathnames, num_parallel_calls=threads)
    # print(dataset)
    if preproc_fn.keywords is not None and 'resize' not in preproc_fn.keywords:
        assert batch_set_size == 1, "Batching images must be of the same size"

    dataset = dataset.map(preproc_fn, num_parallel_calls=threads)

    if shuffle:
        dataset = dataset.shuffle(num_x)

    # It's necessary to repeat our data for all epochs
    #dataset = dataset.batch(batch_set_size)
    #dataset = dataset.repeat()
    #dataset = dataset.prefetch(2)#tf.data.experimental.AUTOTUNE

    dataset = dataset.repeat().batch(batch_size)

    return dataset


def get_baseline_dataset(filenames,
                         labels,
                         preproc_fn=functools.partial(_augment),
                         threads=6,
                         batch_set_size=batch_size,
                         shuffle=False):
    num_x = len(filenames)
    # Create a dataset from the filenames and labels
    dataset = tf.data.Dataset.from_tensor_slices((filenames, labels))

    # Map our preprocessing function to every element in our dataset, taking
    # advantage of multithreading
    dataset = dataset.map(_process_pathnames, num_parallel_calls=threads)
    # print(dataset)
    if preproc_fn.keywords is not None and 'resize' not in preproc_fn.keywords:
        assert batch_set_size == 1, "Batching images must be of the same size"

    dataset = dataset.map(preproc_fn, num_parallel_calls=threads)

    if shuffle:
        dataset = dataset.shuffle(num_x)

    # It's necessary to repeat our data for all epochs
    #dataset = dataset.batch(batch_set_size)
    #dataset = dataset.repeat()
    #dataset = dataset.prefetch(2) #tf.data.experimental.AUTOTUNE
    dataset = dataset.repeat().batch(batch_size)
    return dataset


# In[15]:

# %%
tr_cfg = {
    'resize': None,
    'scale': 1 / 255.,
    'hue_delta': 0.2,
    'horizontal_flip': True,
    'width_shift_range': 0.1,
    'height_shift_range': 0.1,
    'brightness_delta': 0.125,
    'lower_contrast': 0.5,
    'upper_contrast': 1.5

}
tr_preprocessing_fn = functools.partial(_augment, **tr_cfg)

# In[16]:


val_cfg = {
    'resize': None,
    'scale': 1 / 255.,
}
val_preprocessing_fn = functools.partial(_augment, **val_cfg)

# In[17]:

# %%
train_ds = get_baseline_dataset(x_train_filenames,
                                y_train_filenames,
                                preproc_fn=tr_preprocessing_fn,
                                batch_set_size=batch_size,
                               shuffle=False)
val_ds = get_baseline_dataset(x_val_filenames,
                              y_val_filenames,
                              preproc_fn=val_preprocessing_fn,
                              batch_set_size=batch_size,shuffle=False)
test_ds = get_baseline_dataset(test_raw_images,test_label_files, 
                               preproc_fn=val_preprocessing_fn,batch_set_size=batch_size,
                               shuffle=False)

# %%
'''
import tensorflow_datasets as tfds
for batch_of_imgs, label in tfds.as_numpy(dataset):
    #print(type(image), type(label), label)
    plt.figure(figsize=(10, 10))
    img = batch_of_imgs[0]

    plt.subplot(1, 2, 1)
    plt.imshow(img)
    print(label.shape,img.shape)

    plt.subplot(1, 2, 2)
    plt.imshow(label[0, :, :, 0])
    plt.show()
'''
# Out:
# '\nimport tensorflow_datasets as tfds\nfor batch_of_imgs, label in tfds.as_numpy(dataset):\n    #print(type(image), type(label), label)\n    plt.figure(figsize=(10, 10))\n    img = batch_of_imgs[0]\n\n    plt.subplot(1, 2, 1)\n    plt.imshow(img)\n    print(label.shape,img.shape)\n\n    plt.subplot(1, 2, 2)\n    plt.imshow(label[0, :, :, 0])\n    plt.show()\n'

# %% [markdown]
# # Model Training

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

import segmentation_models as sm
from segmentation_models import Unet,FPN,Linknet
from tensorflow.keras.optimizers import Adam
from segmentation_models.losses import bce_jaccard_loss, bce_dice_loss,binary_focal_loss
from segmentation_models.metrics import iou_score
# reduces learning rate on plateau
lr_reducer = ReduceLROnPlateau(factor=0.1,
                               cooldown= 10,
                               patience=10,verbose =1,
                               min_lr=0.1e-5)
mode_autosave = ModelCheckpoint("model-b1.{epoch:02d}.h5",monitor='val_iou_score', 
                                   mode = 'max', save_best_only=True)

# stop learining as metric on validatopn stop increasing
early_stopping = EarlyStopping(patience=5, verbose=1, mode = 'auto') 

metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]

callbacks = [mode_autosave, lr_reducer, early_stopping]

n_classes =1
activation = 'sigmoid' if n_classes == 1 else 'softmax'
tf.keras.backend.clear_session()
metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]
model = Linknet(backbone_name = 'efficientnetb0', encoder_weights='imagenet',classes=n_classes,activation=activation)
model.compile(optimizer = Adam(),
                    loss=binary_focal_loss, metrics=[metrics])

# %%
history = model.fit_generator(train_ds, shuffle =True,
                  epochs=20, workers=2, use_multiprocessing=False,
                 steps_per_epoch = len(x_train_filenames) // batch_size,
                  validation_data = val_ds,
                              validation_steps = len(x_val_filenames) // batch_size,
                  verbose = 1, callbacks=callbacks)
# Out:
# Epoch 1/20
# 3082/3082 [==============================] - 1073s 348ms/step - loss: 0.0097 - iou_score: 0.3156 - f1-score: 0.4578 - val_loss: 0.0082 - val_iou_score: 0.4058 - val_f1-score: 0.5641 - lr: 0.0010
# Epoch 2/20
# 3082/3082 [==============================] - 1072s 348ms/step - loss: 0.0079 - iou_score: 0.4149 - f1-score: 0.5735 - val_loss: 0.0081 - val_iou_score: 0.3709 - val_f1-score: 0.5263 - lr: 0.0010
# Epoch 3/20
# 3082/3082 [==============================] - 1073s 348ms/step - loss: 0.0075 - iou_score: 0.4354 - f1-score: 0.5935 - val_loss: 0.0076 - val_iou_score: 0.4405 - val_f1-score: 0.5972 - lr: 0.0010
# Epoch 4/20
# 3082/3082 [==============================] - 1153s 374ms/step - loss: 0.0073 - iou_score: 0.4459 - f1-score: 0.6044 - val_loss: 0.0074 - val_iou_score: 0.4213 - val_f1-score: 0.5787 - lr: 0.0010
# Epoch 5/20
# 3082/3082 [==============================] - 1302s 422ms/step - loss: 0.0072 - iou_score: 0.4517 - f1-score: 0.6093 - val_loss: 0.0075 - val_iou_score: 0.4626 - val_f1-score: 0.6174 - lr: 0.0010
# Epoch 6/20
# 3082/3082 [==============================] - 1068s 346ms/step - loss: 0.0071 - iou_score: 0.4568 - f1-score: 0.6143 - val_loss: 0.0074 - val_iou_score: 0.4312 - val_f1-score: 0.5874 - lr: 0.0010
# Epoch 7/20
# 3082/3082 [==============================] - 1071s 348ms/step - loss: 0.0070 - iou_score: 0.4599 - f1-score: 0.6168 - val_loss: 0.0072 - val_iou_score: 0.4818 - val_f1-score: 0.6369 - lr: 0.0010
# Epoch 8/20
# 3082/3082 [==============================] - 1073s 348ms/step - loss: 0.0069 - iou_score: 0.4668 - f1-score: 0.6239 - val_loss: 0.0073 - val_iou_score: 0.4728 - val_f1-score: 0.6298 - lr: 0.0010
# Epoch 9/20
# 3082/3082 [==============================] - 1072s 348ms/step - loss: 0.0069 - iou_score: 0.4673 - f1-score: 0.6238 - val_loss: 0.0072 - val_iou_score: 0.4905 - val_f1-score: 0.6448 - lr: 0.0010
# Epoch 10/20
# 3082/3082 [==============================] - 1073s 348ms/step - loss: 0.0068 - iou_score: 0.4734 - f1-score: 0.6301 - val_loss: 0.0071 - val_iou_score: 0.4885 - val_f1-score: 0.6436 - lr: 0.0010
# Epoch 11/20
# 3082/3082 [==============================] - 1073s 348ms/step - loss: 0.0067 - iou_score: 0.4751 - f1-score: 0.6315 - val_loss: 0.0073 - val_iou_score: 0.4746 - val_f1-score: 0.6286 - lr: 0.0010
# Epoch 12/20
# 3082/3082 [==============================] - 1072s 348ms/step - loss: 0.0067 - iou_score: 0.4804 - f1-score: 0.6366 - val_loss: 0.0071 - val_iou_score: 0.4502 - val_f1-score: 0.6045 - lr: 0.0010
# Epoch 13/20
# 3082/3082 [==============================] - 1073s 348ms/step - loss: 0.0067 - iou_score: 0.4810 - f1-score: 0.6366 - val_loss: 0.0071 - val_iou_score: 0.4374 - val_f1-score: 0.5932 - lr: 0.0010
# Epoch 14/20
# 3082/3082 [==============================] - 1073s 348ms/step - loss: 0.0066 - iou_score: 0.4850 - f1-score: 0.6412 - val_loss: 0.0072 - val_iou_score: 0.4378 - val_f1-score: 0.5928 - lr: 0.0010
# Epoch 15/20
# 3082/3082 [==============================] - 1089s 353ms/step - loss: 0.0065 - iou_score: 0.4862 - f1-score: 0.6419 - val_loss: 0.0071 - val_iou_score: 0.4579 - val_f1-score: 0.6136 - lr: 0.0010
# Epoch 16/20
# 3082/3082 [==============================] - 1105s 358ms/step - loss: 0.0065 - iou_score: 0.4902 - f1-score: 0.6458 - val_loss: 0.0070 - val_iou_score: 0.4563 - val_f1-score: 0.6107 - lr: 0.0010
# Epoch 17/20
# 3082/3082 [==============================] - 1074s 349ms/step - loss: 0.0065 - iou_score: 0.4898 - f1-score: 0.6450 - val_loss: 0.0072 - val_iou_score: 0.4486 - val_f1-score: 0.6031 - lr: 0.0010
# Epoch 18/20
# 3082/3082 [==============================] - 1073s 348ms/step - loss: 0.0064 - iou_score: 0.4933 - f1-score: 0.6488 - val_loss: 0.0072 - val_iou_score: 0.4319 - val_f1-score: 0.5876 - lr: 0.0010
# Epoch 19/20
# 3082/3082 [==============================] - 1072s 348ms/step - loss: 0.0064 - iou_score: 0.4930 - f1-score: 0.6478 - val_loss: 0.0071 - val_iou_score: 0.4527 - val_f1-score: 0.6080 - lr: 0.0010
# Epoch 20/20
# 3082/3082 [==============================] - 1071s 348ms/step - loss: 0.0064 - iou_score: 0.4967 - f1-score: 0.6521 - val_loss: 0.0071 - val_iou_score: 0.4474 - val_f1-score: 0.6045 - lr: 0.0010

# %%
model.load_weights('model-b1.09.h5')

# %%
plt.figure(figsize=(30, 5))
plt.subplot(121)
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# # Performance Metrics

# %%
scores = model.evaluate_generator(test_ds,len(test_raw_images)//batch_size)

# %%
predictions=[]
gt=[]
def predict(fname,threshold=0.1):
    img_str = tf.io.read_file(fname)
    img = tf.image.decode_png(img_str, channels=3)
    img = np.multiply(img, 1 / 255.)
    new_img = np.expand_dims(img, axis=0)
    predicted_label = model.predict(new_img)
    #predicted_label = np.reshape(predicted_label, (512, 512))
    final_img = np.zeros((512, 512,1), np.uint8)
    gs_img = np.multiply(predicted_label, 255)
    thresh_indices = predicted_label[:, :] > threshold
    final_img[thresh_indices[0]] = 255
    return Image.fromarray(np.squeeze(final_img, axis=2))

def predictimg(img,threshold=0.1):
    #img_str = tf.io.read_file(fname)
    #img = tf.image.decode_png(img_str, channels=3)
    img = np.multiply(img, 1 / 255.)
    new_img = np.expand_dims(img, axis=0)
    predicted_label = model.predict(new_img)
    #predicted_label = np.reshape(predicted_label, (512, 512))
    final_img = np.zeros((512, 512,1), np.uint8)
    gs_img = np.multiply(predicted_label, 255)
    thresh_indices = predicted_label[:, :] > threshold
    final_img[thresh_indices[0]] = 255
    return Image.fromarray(np.squeeze(final_img, axis=2))

for f in test_raw_images:
    predictions.append(np.array(predict(f,threshold=0.35)))
    
    label_img_str = tf.io.read_file(f.replace('images','masks'))
    # These are gif images so they return as (num_frames, h, w, c)
    label_img = tf.image.decode_png(label_img_str)
    # The label image should only have values of 1 or 0, indicating pixel wise
    # object (car) or not (background). We take the first channel only.
    label_img = label_img[:, :, 0]
    label_img = tf.expand_dims(label_img, axis=-1)
    gt.append(np.array(label_img))
    
from statistics import mean
def getPR(predictions,gt):
    precisions = []
    recalls = []
    for i in range(len(predictions)):
        pred_flat = predictions[i].flatten()
        gt_flat = gt[i].flatten()
        tp = np.sum(np.logical_and(gt_flat == 255, pred_flat == 255))
        tn = np.sum(np.logical_and(gt_flat == 0, pred_flat == 0))
        fp = np.sum(np.logical_and(gt_flat == 0, pred_flat == 255))
        fn = np.sum(np.logical_and(gt_flat == 255, pred_flat == 0))
        precision = tp /  (tp + fp)
        recall = tp /  (tp + fn)
        recalls.append(recall)
        precisions.append(precision)
    return mean([x for x in precisions if ~np.isnan(x)]),mean([x for x in recalls if ~np.isnan(x)])

# %%
p,r=getPR(predictions,gt)
print("Precision:{}".format(p))
print("Recall: {}".format(r))
print("Loss: {:.5}".format(scores[0]))
for metric, value in zip(metrics, scores[1:]):
    print("mean {}: {:.5}".format(metric.__name__, value))
# Out:
# Precision:0.7180415486388017
# Recall: 0.7492738064828761
# Loss: 0.0088657
# mean iou_score: 0.45604
# mean f1-score: 0.6144
# <ipython-input-31-d6aa99ec42ac>:53: RuntimeWarning: invalid value encountered in long_scalars
#   recall = tp /  (tp + fn)
# <ipython-input-31-d6aa99ec42ac>:52: RuntimeWarning: invalid value encountered in long_scalars
#   precision = tp /  (tp + fp)

# %% [markdown]
# # Display sample Prediction

# %%
display_num = 5

def plotPredictimages(imgs,masks,threshold=0.1):
    r_choices = np.random.choice(len(imgs), display_num)

    plt.figure(figsize=(10, 15))
    for i in range(0, display_num * 3, 3):
      img_num = r_choices[i // 3]
      x_pathname = imgs[img_num]
      y_pathname = masks[img_num]

      plt.subplot(display_num, 3, i + 1)
      plt.imshow(mpimg.imread(x_pathname))
      plt.title("Original Image")

      example_labels = Image.open(y_pathname)
      label_vals = np.unique(example_labels)

      plt.subplot(display_num, 3, i + 2)
      plt.imshow(example_labels)
      plt.title("Masked Image")
      
      predict_labels = predict(x_pathname,threshold)
      pred_vals = np.unique(predict_labels)

      plt.subplot(display_num, 3, i + 3)
      plt.imshow(predict_labels)
      plt.title("Predicted Image")
    #plt.savefig('pred.png')
    plt.suptitle("Prediction of road and Masks")
    plt.show()
plotPredictimages(test_raw_images,test_label_files,0.4)

# %% [markdown]
# # Split and Merge Inference 1500*1500 raw image

# %%
def merge_images(files,w=1500,h=1500):
    image1 = files[0]
    image2 = files[1]
    image3 = files[2]
    
    image4 = files[3]
    image5 = files[4]
    image6 = files[5]
    
    image7 = files[6]
    image8 = files[7]
    image9 = files[8]
    
    result = Image.new('RGB', (width*3, height*3))
    result.paste(im=image1, box=(0, 0))
    result.paste(im=image2, box=(width*1, 0))
    result.paste(im=image3, box=(width*2, 0))
    
    result.paste(im=image4, box=(0, height*1))
    result.paste(im=image5, box=(width*1, height*1))
    result.paste(im=image6, box=(width*2, height*1))
    
    
    result.paste(im=image7, box=(0, height*2))
    result.paste(im=image8, box=(width*1, height*2))
    result.paste(im=image9, box=(width*2, height*2))
     
    return result.crop((0, 0, w, h))



def split_pred(infile_path,height=512,width=512):
    result=[]
    for k, piece in enumerate(crop(infile_path,
                                       height, width), 1):
        img = Image.new('RGB', (height, width), 0)
        img.paste(piece)
        
        result.append(predictimg(img,0.37))
    return result
 
def plotInferenceMerged(raw,org_mask,merged):
    fig, axs = plt.subplots(1,3, figsize=(30,20))
    axs[0].imshow(raw)
    axs[0].set_title("Input Image")
    axs[1].imshow(org_mask)
    axs[1].set_title("GT Image")
    axs[2].imshow(merged)
    axs[2].set_title("predicted Image")
    plt.savefig('pred2.png')
    plt.show()

# %%
tile_img=split_pred('/home/ricky/workspace/sat/data/road_segmentation_ideal/testing/input/img-8.png')
merged = merge_images(tile_img)
org_mask = Image.open('/home/ricky/workspace/sat/data/road_segmentation_ideal/testing/output/img-8.png')
raw = Image.open('/home/ricky/workspace/sat/data/road_segmentation_ideal/testing/input/img-8.png')

# %%
plotInferenceMerged(raw,org_mask,merged)
